# %%
import datajoint as dj

# %%
dj.config['database.host'] = 'tutorial-db.datajoint.io'
dj.config['database.user'] = 'dimitri'
dj.config['names.djcat_lab'] = 'catalog_lab_dimitri'
dj.config['names.djcat_alm1'] = 'catalog_alm1_dimitri'

# %%
import djcat_lab as lab
from alm1 import *
# Out:
# Connecting dimitri@tutorial-db.datajoint.io:3306

# %%
erd = dj.ERD(lab)
erd.save('erd-lab.png')
erd

# %%
erd = dj.ERD(schema)
erd.save('erd-alm1.png')
erd

# %%
erd = dj.ERD(schema)-1+lab.User()
erd.save('erd-1.png')
erd

# %%
erd = dj.ERD(lab) + dj.ERD(schema)
erd.save('erd.png')
erd
