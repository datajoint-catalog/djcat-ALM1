# %%
import datajoint as dj

dj.config['database.host'] = 'tutorial-db.datajoint.io'   # replace with your data server
dj.config['database.user'] = 'dimitri'                    # replace with your username
dj.config['names.djcat_lab'] = 'catalog_lab_dimitri'      # replace with your lab schema
dj.config['names.djcat_alm1'] = 'catalog_alm1_dimitri'    # replace with your ALM1 schema

import djcat_lab as lab
from alm1 import *
# Out:
# Connecting dimitri@tutorial-db.datajoint.io:3306

# %%
# Plot the lab schema
erd = dj.ERD(lab)
erd.save('erd-lab.png')
erd

# %%
# Plot the ALM1 schema
erd = dj.ERD(schema)
erd.save('erd-alm1.png')
erd

# %%
# Plot the ALM1 schema plus one layer up
erd = dj.ERD(schema)-1+lab.User()
erd.save('erd-1.png')
erd

# %%
# Plot the entire ALM1 pipeline
erd = dj.ERD(lab) + dj.ERD(schema)
erd.save('erd.png')
erd
